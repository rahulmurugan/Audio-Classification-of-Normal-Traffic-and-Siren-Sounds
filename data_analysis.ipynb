# %%
import seaborn as sns
import matplotlib.pyplot as plt

labels = ['Ambulance', 'Normal Traffic']
values = [932, 903]

plt.figure(figsize=(8, 6))
sns.barplot(x=labels, y=values, palette=[ '#4c72b0', '#dd8452'])  # Use Seaborn's barplot
plt.xlabel('CSV File')
plt.ylabel('Number of Samples')
plt.title('Comparison of Number of Samples')
plt.show()
# Out:
# <ipython-input-65-b0075579ccca>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=labels, y=values, palette=[ '#4c72b0', '#dd8452'])  # Use Seaborn's barplot

# %%
#for the audio dataset
# Create the bar chart
labels = ['Ambulance', 'Normal Traffic']
values = [932, 903]

plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.bar(labels, values, color=['orange', 'blue'])
plt.xlabel('CSV File')
plt.ylabel('Number of Samples')
plt.title('Comparison of Number of Samples in CSV Files')
plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
file_path = '/content/ambulance841.wav'
signal, sample_rate = librosa.load(file_path, sr=None)

# %%
# Set up the parameters for the spectrogram
n_fft = 2048  # Number of samples per FFT window
hop_length = 512  # Number of samples between successive frames

# Compute the spectrogram
stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)
spectrogram = librosa.amplitude_to_db(abs(stft))

# %%
plt.figure(figsize=(10, 8))
librosa.display.specshow(spectrogram, sr=sample_rate, hop_length=hop_length,
                         x_axis='time', y_axis='hz')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
file_path2 = '/content/road883.wav'
signal, sample_rate = librosa.load(file_path2, sr=None)

# %%
# Set up the parameters for the spectrogram
n_fft = 2048  # Number of samples per FFT window
hop_length = 512  # Number of samples between successive frames

# Compute the spectrogram
stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)
spectrogram = librosa.amplitude_to_db(abs(stft))

# %%
plt.figure(figsize=(12, 8))
librosa.display.specshow(spectrogram, sr=sample_rate, hop_length=hop_length,
                         x_axis='time', y_axis='hz')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Discarded script

# %%
# import librosa.display, os
# import numpy as np
# import matplotlib.pyplot as plt

# %%
# def create_spectrogram(audio_file, image_file):
#     fig = plt.figure()
#     ax = fig.add_subplot(1, 1, 1)
#     fig.subplots_adjust(left=0, right=1, bottom=0, top=1)

#     y, sr = librosa.load(audio_file)
#     ms = librosa.feature.melspectrogram(y, sr=sr)
#     log_ms = librosa.power_to_db(ms, ref=np.max)
#     librosa.display.specshow(log_ms, sr=sr)

#     fig.savefig(image_file)
#     plt.close(fig)

# def create_pngs_from_wavs(input_path, output_path):
#     if not os.path.exists(output_path):
#         os.makedirs(output_path)

#     dir = os.listdir(input_path)

#     for i, file in enumerate(dir):
#         input_file = os.path.join(input_path, file)
#         output_file = os.path.join(output_path, file.replace('.wav', '.png'))
#         create_spectrogram(input_file, output_file)

# %% [markdown]
# ### Code from a paper

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load your audio file
y, sr = librosa.load('/content/ambulance841.wav', sr=None)

# Generate the Mel spectrogram
mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=512, n_mels=128)

# Convert to decibels for better visualization
mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)

# Plot the Mel spectrogram
plt.figure(figsize=(10, 8))
librosa.display.specshow(mel_spectrogram_db, sr=sr, hop_length=512, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel Spectrogram')
plt.tight_layout()
plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load your audio file
y, sr = librosa.load('/content/road883.wav', sr=None)

# Generate the Mel spectrogram
mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=512, n_mels=128)

# Convert to decibels for better visualization
mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)

# Plot the Mel spectrogram
plt.figure(figsize=(10, 8))
librosa.display.specshow(mel_spectrogram_db, sr=sr, hop_length=512, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel Spectrogram')
plt.tight_layout()
plt.show()

# %%
import librosa
import librosa.display

filename = '/content/ambulance841.wav'
y, sr = librosa.load(filename)
# trim silent edges
waveform_amb, _ = librosa.effects.trim(y)
librosa.display.waveshow(waveform_amb, sr=sr);

# %%
import librosa
import librosa.display

filename = '/content/road883.wav'
y, sr = librosa.load(filename)
# trim silent edges
waveform_road, _ = librosa.effects.trim(y)
librosa.display.waveshow(waveform_road, sr=sr);

# %%
#download all the above images

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

# Load an audio file
audio_path = '/content/ambulance922.wav'
y, sr = librosa.load(audio_path)

# Generate the mel spectrogram
mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=512, n_mels=128)

# Convert the amplitude to decibels (log-scaling)
log_mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)

# Plot the original and log-scaled mel spectrograms
plt.figure(figsize=(12, 6))

# Original mel spectrogram
plt.subplot(1, 2, 1)
librosa.display.specshow(mel_spectrogram, sr=sr, hop_length=512, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel Spectrogram (Original)')

# Log-scaled mel spectrogram
plt.subplot(1, 2, 2)
librosa.display.specshow(log_mel_spectrogram, sr=sr, hop_length=512, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Log-Scaled Mel Spectrogram')

plt.tight_layout()
plt.show()

# %%
df= pd.read_csv("/content/Ambulance_final.csv")
df.head()
# Out:
#            filename  chroma_stft  spectral_centroid  spectral_bandwidth  \
# 0  ambulance142.wav     0.345168           0.308853         1287.145377
# 1  ambulance449.wav     0.386696           0.263407         2223.479605
# 2  ambulance888.wav     0.517708           0.281876         1393.990435
# 3  ambulance474.wav     0.229988           0.184972         2211.761868
# 4  ambulance305.wav     0.149670           0.115018         1266.959915
#
#        rolloff  zero_crossing_rate     mfcc1       mfcc2       mfcc3  \
# 0  1261.699532         2379.211895  0.081083  -74.003632  163.974854
# 1  2115.848084         4718.463135  0.122690   10.772755  101.783501
# 2  1586.770873         2898.286321  0.064444  -52.157757  144.876480
# 3  1923.778124         3913.245568  0.116267 -130.663757   88.106293
# 4  1654.095586         1831.978666  0.094191 -213.125717  138.419174
#
#        mfcc4  ...     mfcc13    mfcc14     mfcc15   mfcc15.1    mfcc16  \
# ...
